# %%
import pandas as pd

df = pd.read_json("https://dsx.weather.com/wxd/Climatology/03-02/60/30093:4:US")

df.head()
# Out:
#   climoDate       date  extBegDate  extEndDate  hiC  hiF  loC  loF  meanC  \
# 0     03/02 2000-03-02  06/04/1957  02/28/1995   14   58    1   35      8
# 1     03/03 2000-03-03  06/04/1957  02/28/1995   14   58    2   35      8
# 2     03/04 2000-03-04  06/04/1957  02/28/1995   14   58    2   35      8
# 3     03/05 2000-03-05  06/04/1957  02/28/1995   15   58    2   35      8
# 4     03/06 2000-03-06  06/04/1957  02/28/1995   15   59    2   35      8
#
#    meanF        ...         precipCm  precipIn  recordHiC  recordHiDate  \
# 0     46        ...             0.46      0.18         26    03/02/1976
# 1     46        ...             0.43      0.17         27    03/03/1976
# 2     47        ...             0.46      0.18         25    03/04/1992
# 3     47        ...             0.43      0.17         27    03/05/1961
# 4     47        ...             0.46      0.18         26    03/06/1974
#
#   recordHiF  recordLoC  recordLoDate recordLoF    stn             stnNm
# ...
