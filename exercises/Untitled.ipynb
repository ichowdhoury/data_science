# %%
import pandas as pd

df = pd.read_csv("https://www.wunderground.com/history/airport/KMGE/2010/1/1/CustomHistory.html?dayend=31&monthend=12&yearend=2010&req_city=&req_state=&req_statename=&reqdb.zip=&reqdb.magic=&reqdb.wmo=&format=1")
df.head()
# Out:
#         EST  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0  2010-1-1                45                 38                29
# 1  2010-1-2                31                 26                21
# 2  2010-1-3                32                 25                18
# 3  2010-1-4                29                 23                17
# 4  2010-1-5                32                 24                16
#
#    Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 0              43              34             18            94
# 1              17              12              9            68
# 2              10               6              0            70
# 3              13              10              7            71
# 4              12               9              6            76
#
#     Mean Humidity   Min Humidity          ...             Max VisibilityMiles  \
# 0              76             45          ...                              10
# ...

# %%
df.describe()
# Out:
#        Max TemperatureF  Mean TemperatureF  Min TemperatureF  Max Dew PointF  \
# count        365.000000         365.000000        365.000000      365.000000
# mean          71.054795          60.890411         50.890411       53.367123
# std           18.746494          17.949075         18.056202       17.926499
# min           28.000000          21.000000         12.000000       10.000000
# 25%           56.000000          46.000000         36.000000       42.000000
# 50%           75.000000          64.000000         51.000000       56.000000
# 75%           88.000000          78.000000         68.000000       70.000000
# max           98.000000          87.000000         78.000000       77.000000
#
#        MeanDew PointF  Min DewpointF  Max Humidity   Mean Humidity  \
# count      365.000000     365.000000    365.000000      365.000000
# mean        49.126027      44.194521     88.487671       68.824658
# std         18.631195      19.604972      9.056780       13.146969
# ...

# %%
df.describe
# Out:
# <bound method DataFrame.describe of             EST  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0      2010-1-1                45                 38                29
# 1      2010-1-2                31                 26                21
# 2      2010-1-3                32                 25                18
# 3      2010-1-4                29                 23                17
# 4      2010-1-5                32                 24                16
# 5      2010-1-6                36                 27                18
# 6      2010-1-7                37                 30                22
# 7      2010-1-8                28                 21                14
# 8      2010-1-9                31                 22                12
# 9     2010-1-10                33                 25                17
# 10    2010-1-11                43                 30                16
# 11    2010-1-12                35                 30                25
# ...

# %%
df2 = pd.DataFrame(columns = [“EST”,”Max TemperatureF”,”Mean TemperatureF”,”Min TemperatureF”,”Max Dew PointF”,”MeanDew PointF”,”Min DewpointF”,”PrecipitationIn”])
# Out:
#   File "<ipython-input-12-e6d4b63bec8b>", line 1
#     df2 = pd.DataFrame(columns = [“EST”,”Max TemperatureF”,”Mean TemperatureF”,”Min TemperatureF”,”Max Dew PointF”,”MeanDew PointF”,”Min DewpointF”,”PrecipitationIn”])
#                                   ^
# SyntaxError: invalid syntax
